# %%
import matplotlib.pyplot as plt

lines = open("./numberK.txt", "r").readlines()
K = []
Sum_of_squared_distances = []

for line in lines:
    line = line.replace("\n", "")
    tmp = line.split(",")
    K.append(int(tmp[0]))
    Sum_of_squared_distances.append(float(tmp[1]))

plt.figure(figsize = (11,11))
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

lines = open("./part-00000", "r").readlines()

v = []

for line in lines:
    array_tmp = []
    tmp = line.split(",")
    array_tmp.append(int(tmp[0]))
    array_tmp.append(float(tmp[1]))
    array_tmp.append(float(tmp[2]))
    array_tmp.append(float(tmp[3]))
    v.append(array_tmp)

df = pd.DataFrame(v, columns=['Cluster', 'Feature1','Feature2',"Feature3"])
print (df)

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
x = np.array(df['Feature1'])
y = np.array(df['Feature2'])
z = np.array(df['Feature3'])

ax.scatter(x,y,z, marker="s", c=df["Cluster"], s=40)

plt.show()
# Out:
#           Cluster  Feature1  Feature2  Feature3
# 0              32  2.534903  2.502289  2.573222
# 1              32  2.536427  2.493134  2.574745
# 2              39  2.529372  2.477303  2.579320
# 3              39  2.525558  2.480737  2.574745
# 4              39  2.532804  2.481690  2.582368
# ...           ...       ...       ...       ...
# 13543768       26  2.521934  2.513732  4.962995
# 13543769       26  2.522316  2.514305  4.963440
# 13543770       26  2.525939  2.510109  4.963484
# 13543771       21  2.532423  2.504959  4.963661
# 13543772       30  2.537953  2.499428  4.963837
#
# [13543773 rows x 4 columns]
