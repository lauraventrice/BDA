# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

lines = open("./numberK.txt", "r").readlines()
K = []
Sum_of_squared_distances = []

for line in lines:
    line = line.replace("\n", "")
    tmp = line.split(",")
    K.append(int(tmp[0]))
    Sum_of_squared_distances.append(float(tmp[1]))

plt.figure(figsize = (11,11))
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
lines = open("./totalExample/part-00000", "r").readlines()

v = []

for line in lines:
    array_tmp = []
    tmp = line.split(",")
    array_tmp.append(int(tmp[0]))
    array_tmp.append(float(tmp[1]))
    array_tmp.append(float(tmp[2]))
    v.append(array_tmp)

df = pd.DataFrame(v, columns=['Cluster', 'Feature1','Feature2'])
print (df)

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111)
x = np.array(df['Feature1'])
y = np.array(df['Feature2'])

ax.scatter(x,y, marker="s", c=df["Cluster"], s=40, cmap='tab20b')

plt.show()
# Out:
#       Cluster  Feature1  Feature2
# 0          14  0.006801  0.030151
# 1          14  0.012903  0.045226
# 2          19  0.099920  0.095477
# 3           3  0.155431  0.115578
# 4          14  0.008402  0.025126
# ...       ...       ...       ...
# 1027        2  0.800060  0.105528
# 1028        0  0.044409  0.095477
# 1029       14  0.007602  0.050251
# 1030        2  0.809162  0.115578
# 1031        0  0.053511  0.115578
#
# [1032 rows x 3 columns]
